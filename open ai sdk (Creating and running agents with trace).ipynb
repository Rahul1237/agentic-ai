# %%
from dotenv import load_dotenv
from agents import Agent,Runner,trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name='Motivator',instructions='You are a motivational speaker',model='gpt-4o-mini')

# %%
result = Runner.run(agent,"what is the meaning of life?")
result
# Out:
# <coroutine object Runner.run at 0x000002AA052ACD50>

# %%
with trace("Motivation"):
     my_result = await Runner.run(agent,"what is the meaning of life?")
     print(my_result.final_output)
# Out:
# The meaning of life is a deeply personal and often complex question that varies for each individual. For some, it may involve seeking happiness, fostering connections, and making a positive impact on others. For others, it could be about personal growth, pursuing passions, or understanding the world around them.
#
# Ultimately, the meaning of life can often be found in how we choose to engage with our experiences, the relationships we build, the values we uphold, and the legacy we aim to leave behind. Embrace the journey, explore what resonates with you, and remember that it's perfectly fine to seek purpose in different places at different times. What matters most is that you find meaning in your own unique way.
